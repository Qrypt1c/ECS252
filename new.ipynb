# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 23.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 21.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 19.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import json

# %%
download = json.load(open("download.json"))
df = pd.DataFrame(download["data"])

# %%
df.head()
# Out:
#    type                                               item  \
# 0     1  {'id': '7292348470306934022', 'desc': '#ballet...
# 1     1  {'id': '7318605787025149230', 'desc': 'eastern...
# 2     1  {'id': '7148076938735766789', 'desc': 'russia ...
# 3     1  {'id': '7335635534443842858', 'desc': 'The one...
# 4     1  {'id': '7148644302850362670', 'desc': 'You won...
#
#                                   common
# 0  {'doc_id_str': '7292348470306934022'}
# 1  {'doc_id_str': '7318605787025149230'}
# 2  {'doc_id_str': '7148076938735766789'}
# 3  {'doc_id_str': '7335635534443842858'}
# 4  {'doc_id_str': '7148644302850362670'}

# %%
df
# Out:
#     type                                               item  \
# 0      1  {'id': '7292348470306934022', 'desc': '#ballet...
# 1      1  {'id': '7318605787025149230', 'desc': 'eastern...
# 2      1  {'id': '7148076938735766789', 'desc': 'russia ...
# 3      1  {'id': '7335635534443842858', 'desc': 'The one...
# 4      1  {'id': '7148644302850362670', 'desc': 'You won...
# 5      1  {'id': '7051242511368490241', 'desc': 'I love ...
# 6      1  {'id': '7310994651509443872', 'desc': '#russia...
# 7      1  {'id': '6916327963428457734', 'desc': 'I’m exp...
# 8      1  {'id': '7334282500442836229', 'desc': 'Saint P...
# 9      1  {'id': '7167089940206062854', 'desc': 'For rus...
# 10     1  {'id': '7335662639793818926', 'desc': 'Does yo...
#
#                                    common
# 0   {'doc_id_str': '7292348470306934022'}
# 1   {'doc_id_str': '7318605787025149230'}
# 2   {'doc_id_str': '7148076938735766789'}
# 3   {'doc_id_str': '7335635534443842858'}
# ...

# %%
df["item"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/tiktok_scrape/lib/python3.10/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 11 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df["item"][11]
#
# File ~/anaconda3/envs/tiktok_scrape/lib/python3.10/site-packages/pandas/core/series.py:1111, in Series.__getitem__(self, key)
#    1108     return self._values[key]
#    1110 elif key_is_scalar:
# -> 1111     return self._get_value(key)
#    1113 # Convert generator to list before going through hashable part
# ...

# %%
download = json.load(open("download_0.json"))
df = pd.DataFrame(download["data"])
df
# Out:
#    type                                               item  \
# 0     1  {'id': '7192919124706659589', 'desc': 'Comunis...
# 1     1  {'id': '7223842682949356805', 'desc': '#россия...
# 2     1  {'id': '7294729242741329159', 'desc': 'Don’t g...
# 3     1  {'id': '7335817256913341726', 'desc': 'U.S. in...
# 4     1  {'id': '6911248682801204481', 'desc': 'Welcome...
# 5     1  {'id': '7336213026959412523', 'desc': 'In the ...
# 6     1  {'id': '7338156802246217003', 'desc': 'Why #Ki...
# 7     1  {'id': '7297706875859045665', 'desc': 'I can s...
# 8     1  {'id': '7086314363040189723', 'desc': '#presid...
# 9     1  {'id': '7230829431424683269', 'desc': 'Latest ...
#
#                                   common
# 0  {'doc_id_str': '7192919124706659589'}
# 1  {'doc_id_str': '7223842682949356805'}
# 2  {'doc_id_str': '7294729242741329159'}
# 3  {'doc_id_str': '7335817256913341726'}
# 4  {'doc_id_str': '6911248682801204481'}
# 5  {'doc_id_str': '7336213026959412523'}
# ...

# %%
download = json.load(open("download_1.json"))
df = pd.DataFrame(download["data"])
df
# Out:
#     type                                               item  \
# 0      1  {'id': '7241663406909050139', 'desc': 'POV: Yo...
# 1      1  {'id': '7338083499955588398', 'desc': 'On a Fo...
# 2      1  {'id': '7336324957070183726', 'desc': 'Russian...
# 3      1  {'id': '7268566007214591237', 'desc': 'Para pe...
# 4      1  {'id': '7214806290856463621', 'desc': 'New rus...
# 5      1  {'id': '7126967448921820422', 'desc': '#fyp', ...
# 6      1  {'id': '7226410541047139610', 'desc': '😮‍💨😮‍💨 ...
# 7      1  {'id': '7253039421442755883', 'desc': 'WHAT di...
# 8      4                                                NaN
# 9      1  {'id': '7207240021139606830', 'desc': 'crazy😳 ...
# 10     1  {'id': '7318605787025149230', 'desc': 'eastern...
# 11     1  {'id': '7312843497072119046', 'desc': '🇷🇺 #rus...
# 12     1  {'id': '7338148679309806894', 'desc': 'Replyin...
#
#                                    common  \
# 0   {'doc_id_str': '7241663406909050139'}
# ...

# %%
download = json.load(open("download_2.json"))
df = pd.DataFrame(download["data"])
df
# Out:
#    type                                               item  \
# 0     1  {'id': '7148644302850362670', 'desc': 'You won...
# 1     1  {'id': '7214686390032911658', 'desc': '#russia...
# 2     1  {'id': '7051242511368490241', 'desc': 'I love ...
# 3     1  {'id': '7299083539893488942', 'desc': 'GUESS W...
# 4     1  {'id': '7148076938735766789', 'desc': 'russia ...
# 5     1  {'id': '7239744836306357531', 'desc': '2 sides...
# 6     1  {'id': '7335635534443842858', 'desc': 'The one...
# 7     1  {'id': '7186870661875502382', 'desc': '#russia...
# 8     1  {'id': '7219451680281070894', 'desc': 'Most be...
# 9     1  {'id': '6916327963428457734', 'desc': 'I’m exp...
#
#                                   common
# 0  {'doc_id_str': '7148644302850362670'}
# 1  {'doc_id_str': '7214686390032911658'}
# 2  {'doc_id_str': '7051242511368490241'}
# 3  {'doc_id_str': '7299083539893488942'}
# 4  {'doc_id_str': '7148076938735766789'}
# 5  {'doc_id_str': '7239744836306357531'}
# ...
